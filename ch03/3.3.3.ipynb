# %%
# NumPyを用いてニューラルネットワークの実装を行う。
# バイアスと活性化関数は省略

import numpy as np

X = np.array([1, 2])
X.shape
# Out:
# (2,)

# %%
W = np.array([
    [1, 3, 5],
    [2, 4, 6]
])
print(W)
W.shape
# Out:
# [[1 3 5]
#  [2 4 6]]
# (2, 3)
