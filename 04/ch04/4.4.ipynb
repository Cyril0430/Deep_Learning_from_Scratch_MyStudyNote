# %%
import os, sys
sys.path.append(os.pardir)
from ch04.policy_iter import argmax

action_value = {0: 0.1, 1: -0.3, 2: 9.9, 3: -1.3}   # 9.9が最大値（キーは2）

max_action = argmax(action_value)
print(max_action)
# Out:
# 2

# %%
# 実際に`policy_iter`メソッドを使って問題を解いていく
import os, sys
sys.path.append(os.pardir)
from common.gridworld import *
from policy_iter import *
from policy_eval import *

env = GridWorld()
gamma = 0.9
pi = policy_iter(env, gamma, is_render=True)
