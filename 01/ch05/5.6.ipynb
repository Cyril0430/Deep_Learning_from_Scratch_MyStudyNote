# %% [markdown]
# # Affine / Softmaxレイヤの実装
# ## 5.6.1 Affineレイヤ
#
# ```python
# >>> import numpy as np
# >>> X = np.random.rand(2)
# >>> W = np.random.rand(2, 3)
# >>> B = np.random.rand(3)
# >>>
# >>> X.shape
# (2,)
# >>> W.shape
# (2, 3)
# >>> B.shape
# (3,)
# >>>
# >>> Y = np.dot(X, W) + B
# >>> Y
# array([1.89597825, 0.7026596 , 0.71619623])
# ```

# %%
# Affineレイヤの実験的実装
import sys, os
sys.path.append(os.pardir)

import numpy as np
from common.layer import Affine, myAffine
