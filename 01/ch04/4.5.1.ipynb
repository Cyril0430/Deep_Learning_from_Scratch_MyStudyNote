# %%
from two_layer_net import *

net = TwoLayerNet(input_size = 784, hidden_size = 100, output_size = 10)
net.params['W1'].shape
# Out:
# (784, 100)

# %%
net.params['b1'].shape
# Out:
# (100,)

# %%
net.params['W2'].shape
# Out:
# (100, 10)

# %%
net.params['b2'].shape
# Out:
# (10,)

# %%
# 推論処理（フォワード処理）は次のように実行される
x = np.random.randn(100, 784)   # 形状が(100, 784)のNumPy行列が生成される
# つまり、画像サイズが、28×28 = 784である画像データが100枚保存される。
y = net.predict(x)  # shape = (100, 10)
print(np.argmax(y, axis = 1))   # 予測結果（ニューラルネットワークちゃんが「これかな？」と予想した（認識した）数字）
# Out:
# [8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8
#  8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8 8]

# %%
# params変数と対応するような、各パラメータの勾配をgrads変数にディクショナリ形式で格納する。
x = np.random.rand(100, 784)    # ダミーの入力データ(100枚分)
t = np.random.rand(100, 10)     # ダミーの教師データ(100枚分)

# %%
grads = net.numerical_gradient(x, t)    # 各パラメータの勾配を計算
# 時間がかかるので、誤差逆伝播法を学んでから、この部分を修正しましょう。
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 grads = net.numerical_gradient(x, t)    # 各パラメータの勾配を計算
#
# File g:\マイドライブ\勉強系\心理学\森口研究室\DeepLearning_from-Zero\ch04\two_layer_net.py:74, in TwoLayerNet.numerical_gradient(self, x, t)
#      72 grads = {}
#      73 # for label_i in labels:
# ---> 74 grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
#      75 grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
#      76 grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
#
# File g:\マイドライブ\勉強系\心理学\森口研究室\DeepLearning_from-Zero\ch04\..\common\gradient.py:15, in numerical_gradient(f, x)
#      12 fxh1 = f(x)
#      14 x[idx] = tmp_val - h
# ---> 15 fxh2 = f(x)
#      16 grad[idx] = (fxh1 - fxh2) / (2*h)
#      18 x[idx] = tmp_val
#
# ...
